# %%
import pandas as pd
import requests as r
from datetime import *     
import numpy as np

# %% [markdown]
# Test to see if data loader methods are working

# %%
from data_utils.DataLoader import DataLoader

# %%
start_date = "2024-01-01T00:00:00Z"
end_date   = "2025-01-01T00:00:00Z"

# %%
df = DataLoader.extract_data(start_date, end_date)
df = DataLoader.transform_data(df)
df = DataLoader.order_df(df)
df.head()
# Out:
#    year  month  day  day_of_week  hour  minute  second  hour_sin  hour_cos  \
# 0  2024      1    1            0    23      59       4 -0.258819  0.965926
# 1  2024      1    1            0    23      53      49 -0.258819  0.965926
# 2  2024      1    1            0    23      48      40 -0.258819  0.965926
# 3  2024      1    1            0    23      38      16 -0.258819  0.965926
# 4  2024      1    1            0    23      33       1 -0.258819  0.965926
#
#    day_of_week_sin  day_of_week_cos  month_sin  month_cos  lag_1  lag_2  \
# 0              0.0              1.0        0.5   0.866025    NaN    NaN
# 1              0.0              1.0        0.5   0.866025 -2.945    NaN
# 2              0.0              1.0        0.5   0.866025 -2.968 -2.945
# 3              0.0              1.0        0.5   0.866025 -2.982 -2.968
# 4              0.0              1.0        0.5   0.866025 -3.019 -2.982
#
#    lag_3  rolling_mean_3  rolling_std_3  result
# 0    NaN             NaN            NaN  -2.945
# 1    NaN             NaN            NaN  -2.968
# 2    NaN       -2.965000       0.018682  -2.982
# 3 -2.945       -2.989667       0.026350  -3.019
# 4 -2.968       -3.012667       0.028042  -3.037
